# %%
# Q1
mydict = {1:"Kunal",2:"17BTECH0098",3:"BTECH",4:"GHAZIABAD"}
for key,values in mydict.items():
    print(values)
# Out:
# Kunal
# 17BTECH0098
# BTECH
# GHAZIABAD

# %%
# Q2
mydict = {"A":1,"B":2,"C":3,"D":4}
sum=0
for key,values in mydict.items():
    sum+=values
sum
# Out:
# 10

# %%
# Q3

def Merge(mydict1 , mydict2):
    return(mydict1.update(mydict2))
mydict1 = {"A":1,"B":2,"C":3,"D":4}
mydict2 = {1:"Kunal",2:"17BTECH0098",3:"BTECH",4:"GHAZIABAD"}
Merge(mydict1,mydict2)
print(mydict1)
# Out:
# {'A': 1, 'B': 2, 'C': 3, 'D': 4, 1: 'Kunal', 2: '17BTECH0098', 3: 'BTECH', 4: 'GHAZIABAD'}

# %%
# Q4
my_dict = {'month_num' : [1, 2, 3, 4], 'name_of_month' : ['Jan', 'Feb', 'March', 'Apr']}
myres = zip(my_dict['month_num'] , my_dict['name_of_month'])
dict(myres)
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'March', 4: 'Apr'}

# %%
# Q5
from collections import OrderedDict
mydict = OrderedDict([('Kunal','1') , ('Sajal','2')])
mydict.update({'Udit':'4'})
mydict.move_to_end('Udit', last = False)
mydict
# Out:
# OrderedDict([('Udit', '4'), ('Kunal', '1'), ('Sajal', '2')])

# %%
# Q6
from collections import OrderedDict 
def checkOrder(input, pattern): 
    dict = OrderedDict.fromkeys(input) 
    ptrlen = 0
    for key,value in dict.items(): 
        if (key == pattern[ptrlen]): 
            ptrlen = ptrlen + 1
        if (ptrlen == (len(pattern))): 
            return 'true'
    return 'false'
  
# Driver program 
if __name__ == "__main__": 
    input = 'engineers'
    pattern = 'egr'
    print (checkOrder(input,pattern))
# Out:
# true

# %%
#Q7
def dictionairy(): 
     mydict ={1:"A",10:"B",3:"C",4:"F"}    
     print ("Sorted Keys are")
     for i in sorted(mydict.values()) : 
         print(i, end = " ")
dictionairy()
# Out:
# Sorted Keys are
# A B C F
