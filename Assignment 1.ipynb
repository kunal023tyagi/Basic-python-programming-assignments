# %%
#Write a Python program to print "Hello Python"?

print("Hello Python")
# Out:
# Hello Python

# %%
#Write a Python program to do arithmetical operations addition and division.?

a= int(input("Enter a number "))
b= int(input("Enter a number "))

print("The sum of the given numbers is ", a+b)
print("The division of the given numbers is ",a/b)
# Out:
# Enter a number 4
# Enter a number 3
# The sum of the given numbers is  7
# The division of the given numbers is  1.3333333333333333

# %%
#Write a Python program to find the area of a triangle?

a= float(input("Enter first side of the triangle "))
b= float(input("Enter second side of the triangle "))
c= float(input("Enter third side of the triangle "))
semi_perimeter= (a+b+c)/2

area= (semi_perimeter*(semi_perimeter-a)*(semi_perimeter-b)*(semi_perimeter-c))**0.5
print(area)
# Out:
# Enter first side of the triangle 3
# Enter second side of the triangle 4
# Enter third side of the triangle 5
# 6.0

# %%
#Write a Python program to swap two variables?

a= input("Enter first variable ")
b= input("Enter sceond variable ")
c=a
a=b
b=c

print(a,b)
# Out:
# Enter first variable 2
# Enter sceond variable arun
# arun 2

# %%
#Write a Python program to generate a random number?

import random
a= int(input("Enter the lower range "))
b= int(input("Enter the upper range "))
print("Generated random number ",random.randint(a,b))
# Out:
# Enter the lower range 0
# Enter the upper range 100
# Generated random number  78
